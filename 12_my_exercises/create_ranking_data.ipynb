# %%
import pandas as pd 
import numpy as np

# %%
dates = pd.date_range(start='20100101', end='20191231', freq='D')
values = np.random.randint(15000, high=5000, size=3652)
# print(dates.size)

# %%
df1 = pd.DataFrame({
    'name':'num', 
    'type':'China', 
    'value':values, 
    'date':dates
})
df1.info()

# %%
df1.tail()

# %%
country_list = [
